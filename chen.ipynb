# %%
import pickle

# %%
with open('data/X_train.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
#        template_id    msrp  bike_created_at_year  bike_created_at_month
# id
# 76662         1799  5333.0                  2022                      6  \
# 55636        55631  2199.0                  2022                      4
# 75311         9981  2099.0                  2022                      5
# 76314        75633  4999.0                  2022                      6
# 39557        24347  3099.0                  2022                      3
# ...            ...     ...                   ...                    ...
# 32229        26638  3500.0                  2022                      1
# 55557         9712  2099.0                  2022                      4
# 34970        17945  4699.0                  2022                      2
# 33279        29401  4000.0                  2022                      2
# 35575        24941  1399.0                  2022                      3
#
#        bike_year  sales_duration  sales_country_id  bike_type_id
# id
# ...

# %%
with open('data/X_test.pkl', 'rb') as f:
    test_data = pickle.load(f)
test_data
# Out:
#        template_id    msrp  bike_created_at_year  bike_created_at_month
# id
# 84497         1658  3219.0                  2022                      7  \
# 90776         1857  3499.0                  2022                      8
# 86179        16748  5600.0                  2022                      7
# 81521        19544  1899.0                  2022                      7
# 82786         1882  4999.0                  2022                      7
# ...            ...     ...                   ...                    ...
# 89326         1809  5259.0                  2022                      8
# 85870        25741  1999.0                  2022                      7
# 87177          495  3799.0                  2022                      7
# 82019         1768  2729.0                  2022                      7
# 82245        11721  2199.0                  2022                      7
#
#        bike_year  sales_duration  sales_country_id  bike_type_id
# id
# ...
